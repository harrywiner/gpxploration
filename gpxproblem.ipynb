# %%
import folium
import gpxpy
# Out:
# /Users/harrywiner/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Read GPX file
with open('./bpt-gpx/St Rumbold\'s Way.gpx', 'r') as gpx_file:
    gpx = gpxpy.parse(gpx_file)

# %%
gpx.tracks[1].segments[0].points
# Out:
# [GPXTrackPoint(52.0235386, -1.1221785, elevation=0.0, name='1'),
#  GPXTrackPoint(52.017923, -1.1246147, elevation=0.0, name='2'),
#  GPXTrackPoint(52.0167042, -1.1250313, elevation=0.0, name='3'),
#  GPXTrackPoint(52.0164348, -1.1253811, elevation=0.0, name='4'),
#  GPXTrackPoint(52.0110546, -1.1232634, elevation=0.0, name='5'),
#  GPXTrackPoint(52.0062896, -1.1204985, elevation=0.0, name='6'),
#  GPXTrackPoint(52.0048203, -1.1195899, elevation=0.0, name='7'),
#  GPXTrackPoint(52.0035603, -1.1188846, elevation=0.0, name='8'),
#  GPXTrackPoint(52.0024523, -1.11863, elevation=0.0, name='9'),
#  GPXTrackPoint(52.0019061, -1.117346, elevation=0.0, name='10'),
#  GPXTrackPoint(52.000872, -1.1148073, elevation=0.0, name='11'),
#  GPXTrackPoint(52.0009751, -1.1132177, elevation=0.0, name='12'),
#  GPXTrackPoint(52.0002651, -1.1050519, elevation=0.0, name='13'),
#  GPXTrackPoint(51.9995714, -1.1017067, elevation=0.0, name='14'),
# ...

# %%
first_point = gpx.tracks[0].segments[0].
m = folium.Map(location=[first_point.latitude, first_point.longitude], zoom_start=14)

# Plot track
for route in gpx.tracks:
    color = None
    if route.name == "StRumwoldsWay.gpx_ALT Rumbold route":
        color = "red"
    else:
        color = "blue"
    points = [(point.latitude, point.longitude) for point in route.points]
    folium.PolyLine(points, color=color, weight=2.5, opacity=0.5).add_to(m)

# Display map
# m.save('GPX_track_map.html')
m  # i
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/harrywiner/Code/BPT/gpxploration/gpxproblem.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/harrywiner/Code/BPT/gpxploration/gpxproblem.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> first_point = gpx.tracks[0].segments[0]
# ----> <a href='vscode-notebook-cell:/Users/harrywiner/Code/BPT/gpxploration/gpxproblem.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> m = folium.Map(location=[first_point.latitude, first_point.longitude], zoom_start=14)
#       <a href='vscode-notebook-cell:/Users/harrywiner/Code/BPT/gpxploration/gpxproblem.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # Plot track
#       <a href='vscode-notebook-cell:/Users/harrywiner/Code/BPT/gpxploration/gpxproblem.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> for route in gpx.tracks:
#
# AttributeError: 'GPXTrackSegment' object has no attribute 'latitude'

# %%
gpx.routes[0].points
# Out:
# [GPXRoutePoint(52.022422, -1.280721, elevation=0.0, name='1'),
#  GPXRoutePoint(52.021642, -1.280379, elevation=0.0, name='2'),
#  GPXRoutePoint(52.020903, -1.280026, elevation=0.0, name='3'),
#  GPXRoutePoint(52.021296, -1.278431, elevation=0.0, name='4'),
#  GPXRoutePoint(52.021716, -1.277627, elevation=0.0, name='5'),
#  GPXRoutePoint(52.021758, -1.276671, elevation=0.0, name='6'),
#  GPXRoutePoint(52.021677, -1.276648, elevation=0.0, name='7'),
#  GPXRoutePoint(52.021347, -1.276591, elevation=0.0, name='8'),
#  GPXRoutePoint(52.021065, -1.275446, elevation=0.0, name='9'),
#  GPXRoutePoint(52.021164, -1.274734, elevation=0.0, name='10'),
#  GPXRoutePoint(52.020054, -1.274099, elevation=0.0, name='11'),
#  GPXRoutePoint(52.019998, -1.273757, elevation=0.0, name='12'),
#  GPXRoutePoint(52.017941, -1.268844, elevation=0.0, name='13'),
#  GPXRoutePoint(52.017218, -1.266661, elevation=0.0, name='14'),
#  GPXRoutePoint(52.016225, -1.265388, elevation=0.0, name='15'),
# ...
